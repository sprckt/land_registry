# %% [markdown]
# # Land Registry Latest

# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sys.executable
# Out:
# '/Users/eric/e-prop/et/venv/bin/python3.6'

# %%
 dict_data_types = {
        'transaction_id': 'string',
        'price': 'long',
        'date_of_transfer': 'timestamp',
        'postcode': 'string',
        'property_type': 'string',
        'old_or_new': 'string',
        'duration': 'string',
        'paon': 'string',
        'saon': 'string',
        'street': 'string',
        'locality': 'string',
        'town_city': 'string',
        'district': 'string',
        'county': 'string',
        'ppd_category': 'string',
        'record_status': 'string'
    }
column_headers = list(dict_data_types.keys())
column_headers
# Out:
# ['transaction_id',
#  'price',
#  'date_of_transfer',
#  'postcode',
#  'property_type',
#  'old_or_new',
#  'duration',
#  'paon',
#  'saon',
#  'street',
#  'locality',
#  'town_city',
#  'district',
#  'county',
#  'ppd_category',
#  'record_status']

# %% [markdown]
# ### Read in data and review

# %%
data = pd.read_csv('latest.csv', names=column_headers)

# %%
data['date_of_transfer'] = pd.to_datetime(data['date_of_transfer'])

# %%
data.sample(4)
# Out:
#                                transaction_id   price date_of_transfer  \
# 15307  {6DA0844A-BDD4-30F2-E053-6B04A8C05F3B}  475000       2018-05-04
# 7796   {6DA0844A-12B4-30F2-E053-6B04A8C05F3B}   72500       2017-09-08
# 68022  {6DA08449-94DE-30F2-E053-6B04A8C05F3B}  275000       2018-05-23
# 30707  {6DA0844A-7744-30F2-E053-6B04A8C05F3B}  142995       2018-03-29
#
#        postcode property_type old_or_new duration paon saon           street  \
# 15307   UB6 0BE             T          N        F   56  NaN      CURREY ROAD
# 7796   NG34 8RE             F          N        L   20  NaN    THE HEDGEROWS
# 68022  MK41 0FG             S          N        F   10  NaN  PRIMROSE FIELDS
# 30707   NE6 3TS             D          Y        F   15  NaN     POTTERY PARK
#
#       locality            town_city             district          county  \
# 15307      NaN            GREENFORD               EALING  GREATER LONDON
# 7796       NaN             SLEAFORD       NORTH KESTEVEN    LINCOLNSHIRE
# 68022      NaN              BEDFORD              BEDFORD         BEDFORD
# 30707      NaN  NEWCASTLE UPON TYNE  NEWCASTLE UPON TYNE   TYNE AND WEAR
#
#       ppd_category record_status
# 15307            B             A
# 7796             A             A
# 68022            A             A
# 30707            A             A

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90858 entries, 0 to 90857
# Data columns (total 16 columns):
# transaction_id      90858 non-null object
# price               90858 non-null int64
# date_of_transfer    90858 non-null datetime64[ns]
# postcode            90196 non-null object
# property_type       90858 non-null object
# old_or_new          90858 non-null object
# duration            90858 non-null object
# paon                90858 non-null object
# saon                14106 non-null object
# street              89016 non-null object
# locality            33737 non-null object
# town_city           90858 non-null object
# district            90858 non-null object
# county              90858 non-null object
# ppd_category        90858 non-null object
# record_status       90858 non-null object
# dtypes: datetime64[ns](1), int64(1), object(14)
# memory usage: 11.1+ MB

# %% [markdown]
# ### Date Range

# %%
# Date range of records
data['date_of_transfer'].min(), data['date_of_transfer'].max()
# Out:
# (Timestamp('1995-01-06 00:00:00'), Timestamp('2018-05-30 00:00:00'))

# %%
# Test the yearly sum of price paid data
yr = 1995
yr_data = data[data['date_of_transfer'].dt.year == yr]
print(f"Year {yr} total: £{yr_data['price'].sum()}")
yr_data.head()
# Out:
# Year 1995 total: £5190080
#                               transaction_id   price date_of_transfer  \
# 2936  {6DA08449-F093-30F2-E053-6B04A8C05F3B}   50000       1995-06-01
# 2937  {6DA08449-991F-30F2-E053-6B04A8C05F3B}   92500       1995-01-11
# 2938  {6DA08449-998F-30F2-E053-6B04A8C05F3B}   38500       1995-08-25
# 2939  {6DA08449-DA33-30F2-E053-6B04A8C05F3B}  175000       1995-05-01
# 2940  {6DA0844A-102A-30F2-E053-6B04A8C05F3B}  185000       1995-03-17
#
#       postcode property_type old_or_new duration           paon saon  \
# 2936  WD19 5EG             T          N        F              7  NaN
# 2937  RG17 8QQ             D          N        F      WOOD VIEW  NaN
# 2938  RG40 1XU             F          Y        L             66  NaN
# 2939   CM9 6NN             D          N        F  BRIAR COTTAGE  NaN
# 2940   PE9 4UD             D          Y        F              1  NaN
#
#               street   locality   town_city        district          county  \
# 2936     GIBBS COUCH        NaN     WATFORD         WATFORD   HERTFORDSHIRE
# 2937        THE PARK   LAMBOURN  HUNGERFORD  WEST BERKSHIRE  WEST BERKSHIRE
# 2938     ROSE STREET        NaN   WOKINGHAM       WOKINGHAM       WOKINGHAM
# 2939  ROUNDBUSH ROAD     MUNDON      MALDON          MALDON           ESSEX
# 2940    THE CHARTERS  UFFINGTON    STAMFORD  SOUTH KESTEVEN    LINCOLNSHIRE
#
#      ppd_category record_status
# 2936            A             A
# 2937            A             A
# 2938            A             A
# 2939            A             A
# 2940            A             A

# %%
# Group price paid by year
f = {'price': ['sum', 'count']}
transfer_by_yr = data[['price']].groupby(data['date_of_transfer'].dt.year).agg(f)
transfer_by_yr
# Out:
#                         price
#                           sum  count
# date_of_transfer
# 1995                  5190080     63
# 1996                  8753398     83
# 1997                  6844045     70
# 1998                 10146360     88
# 1999                 10299688     81
# 2000                 12300706     75
# 2001                 25476179    150
# 2002                 20161913    121
# 2003                 19900418    112
# 2004                 19701549     97
# 2005                 23202635    107
# 2006                 33794376    132
# 2007                 30406579    136
# 2008                 18735015     78
# 2009                  9601000     45
# 2010                 17489791     59
# 2011                 70887125     56
# 2012                 16991495     56
# 2013                 41063673    114
# 2014                 84650392    141
# 2015                223868712    314
# 2016                391336194    735
# 2017               2970194171   7616
# 2018              28609568401  80329

# %%
# Graph the above
plt.figure(figsize=(15,10))
plt.plot((transfer_by_yr['price']['sum']))
plt.xlabel('Aggregate by Year')
plt.ylabel('Log of yearly price')
plt.title('Total spent by year')
# Out:
# Text(0.5,1,'Total spent by year')

# %% [markdown]
# ### Record type

# %%
# Number of amendments
amendments = data[data['record_status'] != 'A']
print(amendments.index.size)
amendments.head()
# Out:
# 7429
#                             transaction_id   price date_of_transfer  postcode  \
# 17  {B40DA8B6-F2A9-45A3-87EF-015A7838F29D}  123500       2002-11-08   EX2 4TE
# 18  {5545F464-D67F-44BE-9710-003A3CCE93FC}  100000       2002-01-31   HD7 5UZ
# 19  {D4D5C6D7-CEB9-4288-9DCA-FCFA0AC0463E}  170000       2002-08-07  NR32 3JN
# 20  {0DFD3509-8739-4F1E-A916-1688DCC99B02}   85950       2002-09-13   BH7 6BT
# 21  {80F14F85-57A3-4510-B15D-254C6BF7EFD3}   55000       2002-02-28  NN11 4DU
#
#    property_type old_or_new duration               paon         saon  \
# 17             F          N        F                 40          NaN
# 18             D          N        F  BURNT PLATTS LANE  THE PIGGERY
# 19             T          N        F                 25          NaN
# 20             F          N        L          664 - 666       FLAT 9
# 21             F          N        L                 20          NaN
#
#                street     locality     town_city     district  \
# 17      MAGDALEN ROAD          NaN        EXETER       EXETER
# 18                NaN  SLAITHWAITE  HUDDERSFIELD     KIRKLEES
# 19        CHURCH LANE          NaN     LOWESTOFT      WAVENEY
# 20  CHRISTCHURCH ROAD          NaN   BOURNEMOUTH  BOURNEMOUTH
# 21           NEWLANDS          NaN      DAVENTRY     DAVENTRY
#
#               county ppd_category record_status
# 17             DEVON            A             C
# 18    WEST YORKSHIRE            A             C
# 19           SUFFOLK            A             C
# 20       BOURNEMOUTH            A             C
# 21  NORTHAMPTONSHIRE            A             C

# %% [markdown]
# ### Counties areas and zones

# %%
# Number of counties in the dataset
counties = data['county'].unique()
counties, len(counties)
# Out:
# (array(['BEDFORD', 'CENTRAL BEDFORDSHIRE', 'WEST BERKSHIRE',
#         'GREATER LONDON', 'GREATER MANCHESTER', 'KENT', 'NORFOLK',
#         'OXFORDSHIRE', 'WREKIN', 'SOMERSET', 'CEREDIGION', 'GWYNEDD',
#         'CUMBRIA', 'DARLINGTON', 'SURREY', 'DEVON', 'WEST YORKSHIRE',
#         'SUFFOLK', 'BOURNEMOUTH', 'NORTHAMPTONSHIRE', 'WARWICKSHIRE',
#         'NOTTINGHAMSHIRE', 'HERTFORDSHIRE', 'RHONDDA CYNON TAFF',
#         'LINCOLNSHIRE', 'DORSET', 'HAMPSHIRE', 'PORTSMOUTH', 'EAST SUSSEX',
#         'CORNWALL', 'FLINTSHIRE', 'NORTH YORKSHIRE', 'GLOUCESTERSHIRE',
#         'WORCESTERSHIRE', 'TORBAY', 'ESSEX', 'SOUTH YORKSHIRE',
#         'WEST SUSSEX', 'CARMARTHENSHIRE', 'MERSEYSIDE',
#         'BRIGHTON AND HOVE', 'WEST MIDLANDS', 'WILTSHIRE',
#         'NORTHUMBERLAND', 'LEICESTER', 'STAFFORDSHIRE', 'BRIDGEND',
#         'SWANSEA', 'WREXHAM', 'NEWPORT', 'SHROPSHIRE', 'CARDIFF',
#         'NORTH SOMERSET', 'CAERPHILLY', 'THE VALE OF GLAMORGAN', 'MEDWAY',
#         'CITY OF PLYMOUTH', 'CITY OF KINGSTON UPON HULL',
#         'CHESHIRE WEST AND CHESTER', 'LANCASHIRE', 'SOUTHAMPTON',
#         'CITY OF BRISTOL', 'TYNE AND WEAR', 'POWYS', 'CHESHIRE EAST',
#         'CITY OF DERBY', 'MIDDLESBROUGH', 'EAST RIDING OF YORKSHIRE',
#         'ISLE OF ANGLESEY', 'SOUTHEND-ON-SEA', 'BUCKINGHAMSHIRE',
#         'ISLE OF WIGHT', 'MONMOUTHSHIRE', 'DERBYSHIRE',
#         'REDCAR AND CLEVELAND', 'WINDSOR AND MAIDENHEAD', 'LEICESTERSHIRE',
#         'LUTON', 'COUNTY DURHAM', 'NORTH LINCOLNSHIRE', 'CAMBRIDGESHIRE',
#         'NORTH EAST LINCOLNSHIRE', 'SOUTH GLOUCESTERSHIRE',
#         'HEREFORDSHIRE', 'BLACKBURN WITH DARWEN', 'TORFAEN',
#         'PEMBROKESHIRE', 'BATH AND NORTH EAST SOMERSET',
#         'CITY OF NOTTINGHAM', 'SWINDON', 'READING', 'THURROCK', 'POOLE',
#         'CHESHIRE', 'WOKINGHAM', 'BRACKNELL FOREST', 'SLOUGH',
#         'CITY OF PETERBOROUGH', 'BLACKPOOL', 'STOKE-ON-TRENT', 'YORK',
#         'STOCKTON-ON-TEES', 'BLAENAU GWENT', 'MILTON KEYNES', 'CONWY',
#         'MERTHYR TYDFIL', 'RUTLAND', 'HALTON', 'WARRINGTON', 'HARTLEPOOL',
#         'NEATH PORT TALBOT', 'MID GLAMORGAN', 'DYFED', 'DENBIGHSHIRE',
#         'ISLES OF SCILLY'], dtype=object), 115)

# %%
# Number of districts
districts = data['district'].unique()
districts, len(districts)
# Out:
# (array(['BEDFORD', 'CENTRAL BEDFORDSHIRE', 'WEST BERKSHIRE', 'HARINGEY',
#         'WIGAN', 'ASHFORD', 'NORTH NORFOLK', 'CHERWELL', 'WREKIN',
#         'WEST SOMERSET', 'CEREDIGION', 'GWYNEDD', 'SOUTH LAKELAND',
#         'KENSINGTON AND CHELSEA', 'DARLINGTON', 'CITY OF WESTMINSTER',
#         'ELMBRIDGE', 'EXETER', 'KIRKLEES', 'WAVENEY', 'BOURNEMOUTH',
#         'DAVENTRY', 'WALTHAM FOREST', 'WARWICK', 'BROXTOWE', 'HACKNEY',
#         'WANDSWORTH', 'ST ALBANS', 'RHONDDA CYNON TAFF', 'OLDHAM',
#         'SOUTH HOLLAND', 'WEYMOUTH AND PORTLAND', 'HAVANT',
#         'WEST OXFORDSHIRE', 'REDBRIDGE', 'PORTSMOUTH', 'EASTBOURNE',
#         'CORNWALL', 'DOVER', 'FLINTSHIRE', 'KETTERING',
#         'SOUTH NORTHAMPTONSHIRE', 'SCARBOROUGH', 'ISLINGTON', 'THANET',
#         'FOREST OF DEAN', 'EALING', 'WYCHAVON', 'TORBAY', 'TENDRING',
#         'DONCASTER', 'MANCHESTER', 'CHICHESTER', 'NORWICH',
#         'CARMARTHENSHIRE', 'ST HELENS', 'BRIGHTON AND HOVE', 'COTSWOLD',
#         'SHEFFIELD', 'BIRMINGHAM', 'MENDIP', 'ALLERDALE', 'WILTSHIRE',
#         'TEIGNBRIDGE', 'BRADFORD', 'NORTHUMBERLAND',
#         'HAMMERSMITH AND FULHAM', 'ROCHDALE', 'LEICESTER', 'TOWER HAMLETS',
#         'MALDON', 'EAST DEVON', 'GREAT YARMOUTH', 'CANNOCK CHASE',
#         'BRIDGEND', 'SWANSEA', 'WREXHAM', 'RICHMONDSHIRE',
#         'NEWCASTLE-UNDER-LYME', 'NEWPORT', 'SOUTH SOMERSET', 'SPELTHORNE',
#         'BRIDGNORTH', 'CARDIFF', 'BABERGH', 'IPSWICH', 'WEST LINDSEY',
#         'TAUNTON DEANE', 'GEDLING', 'NORTH SOMERSET', 'CAERPHILLY',
#         'MERTON', 'THE VALE OF GLAMORGAN', 'MEDWAY', 'TUNBRIDGE WELLS',
#         'LEWES', 'TORRIDGE', 'SOUTHWARK', 'NORTH KESTEVEN', 'NEWHAM',
#         'BASSETLAW', 'DUDLEY', 'STROUD', 'SEVENOAKS', 'WORTHING',
#         'CITY OF PLYMOUTH', 'CITY OF KINGSTON UPON HULL',
#         'CHESHIRE WEST AND CHESTER', 'LANCASTER', 'SOUTH RIBBLE',
#         'SOUTHAMPTON', 'CITY OF BRISTOL', 'EAST DORSET', 'EAST LINDSEY',
#         'SUNDERLAND', 'POWYS', 'LEEDS', 'CHESHIRE EAST', 'CHRISTCHURCH',
#         'CITY OF DERBY', 'LINCOLN', 'STAFFORD', 'EAST HAMPSHIRE',
#         'MIDDLESBROUGH', 'EAST RIDING OF YORKSHIRE', 'COLCHESTER',
#         'SOUTH KESTEVEN', 'EDEN', 'LICHFIELD', 'CROYDON', 'DARTFORD',
#         'FOREST HEATH', 'ISLE OF ANGLESEY', 'HILLINGDON',
#         'SOUTHEND-ON-SEA', 'HASTINGS', 'SHROPSHIRE', 'WOLVERHAMPTON',
#         'WYCOMBE', 'ISLE OF WIGHT', 'EPPING FOREST', 'MONMOUTHSHIRE',
#         'BROMSGROVE', 'HORSHAM', 'BOLSOVER', 'STAFFORDSHIRE MOORLANDS',
#         'BEXLEY', 'BRENTWOOD', 'CORBY', 'EAST HERTFORDSHIRE',
#         'REDCAR AND CLEVELAND', 'WINDSOR AND MAIDENHEAD', 'HARROGATE',
#         'CHARNWOOD', 'LEWISHAM', 'UTTLESFORD', 'DACORUM', 'MID DEVON',
#         "KING'S LYNN AND WEST NORFOLK", 'REIGATE AND BANSTEAD', 'LUTON',
#         'WOKING', 'CHELTENHAM', 'SHEPWAY', 'COUNTY DURHAM', 'HARBOROUGH',
#         'MOLE VALLEY', 'HAVERING', 'BOLTON', 'NORTH LINCOLNSHIRE',
#         'RICHMOND UPON THAMES', 'MALVERN HILLS', 'HOUNSLOW',
#         'NORTH HERTFORDSHIRE', 'KINGSTON UPON THAMES', 'ASHFIELD',
#         'CHORLEY', 'SANDWELL', 'HUNTINGDONSHIRE', 'ROSSENDALE',
#         'SOUTH CAMBRIDGESHIRE', 'CHELMSFORD', 'NORTH EAST LINCOLNSHIRE',
#         'NORTH DEVON', 'SOUTH GLOUCESTERSHIRE', 'CAMDEN', 'BRECKLAND',
#         'SEDGEMOOR', 'BARNSLEY', 'COPELAND', 'SOUTH STAFFORDSHIRE',
#         'WORCESTER', 'HEREFORDSHIRE', 'BLACKBURN WITH DARWEN', 'BURY',
#         'AMBER VALLEY', 'LAMBETH', 'BARNET', 'SELBY',
#         'TONBRIDGE AND MALLING', 'CHILTERN', 'CAMBRIDGE', 'WATFORD',
#         'TEWKESBURY', 'TORFAEN', 'HART', 'EAST STAFFORDSHIRE',
#         'PEMBROKESHIRE', 'CALDERDALE', 'BROMLEY', 'WAVERLEY', 'BRENT',
#         'RUNNYMEDE', 'THREE RIVERS', 'LIVERPOOL', 'FENLAND',
#         'BATH AND NORTH EAST SOMERSET', 'SOUTH OXFORDSHIRE', 'WEALDEN',
#         'CITY OF NOTTINGHAM', 'TAMESIDE', 'WYRE', 'OXFORD', 'SOUTH BUCKS',
#         'STRATFORD-ON-AVON', 'TEST VALLEY', 'SWINDON', 'BURNLEY',
#         'SUFFOLK COASTAL', 'SOUTH HAMS', 'READING', 'THURROCK',
#         'VALE OF WHITE HORSE', 'SEFTON', 'POOLE', 'CRAVEN', 'GUILDFORD',
#         'ARUN', 'SOUTH NORFOLK', 'CARADON', 'BROXBOURNE', 'BOSTON',
#         'STOCKPORT', 'NORTH WEST LEICESTERSHIRE', 'BRAINTREE',
#         'MID SUSSEX', 'GLOUCESTER', 'SALFORD', 'KNOWSLEY', 'WIRRAL',
#         'EAST NORTHAMPTONSHIRE', 'BLABY', 'CREWE AND NANTWICH', 'HARROW',
#         'ENFIELD', 'WOKINGHAM', 'BRACKNELL FOREST', 'SLOUGH',
#         'CITY OF PETERBOROUGH', 'EAST CAMBRIDGESHIRE', 'BLACKPOOL',
#         'CASTLE POINT', 'PURBECK', 'TRAFFORD', 'STOKE-ON-TRENT',
#         'NORTHAMPTON', 'MANSFIELD', 'YORK', 'SURREY HEATH',
#         'EPSOM AND EWELL', 'ROTHERHAM', 'GREENWICH', 'MAIDSTONE', 'SWALE',
#         'NEWCASTLE UPON TYNE', 'NORTH WARWICKSHIRE', 'RUGBY',
#         'WYRE FOREST', 'WAKEFIELD', 'AYLESBURY VALE', 'STOCKTON-ON-TEES',
#         'BROADLAND', 'SOUTH TYNESIDE', 'BLAENAU GWENT',
#         'NEWARK AND SHERWOOD', 'MILTON KEYNES', 'NORTH EAST DERBYSHIRE',
#         'CITY OF LONDON', 'REDDITCH', 'HINCKLEY AND BOSWORTH', 'SOLIHULL',
#         'TAMWORTH', 'ROTHER', 'CONWY', 'SOUTH DERBYSHIRE', 'WINCHESTER',
#         'RUSHMOOR', 'RIBBLE VALLEY', 'PRESTON', 'WELLINGBOROUGH',
#         'RUSHCLIFFE', 'WALSALL', 'MERTHYR TYDFIL', 'EREWASH', 'NEW FOREST',
#         'RUTLAND', 'COVENTRY', 'HALTON', 'WARRINGTON', 'CHESTERFIELD',
#         'HIGH PEAK', 'VALE ROYAL', 'TANDRIDGE', 'PENDLE', 'GRAVESHAM',
#         'NUNEATON AND BEDWORTH', 'BARKING AND DAGENHAM', 'FYLDE',
#         'HARTLEPOOL', 'EASTLEIGH', 'FAREHAM', 'BASINGSTOKE AND DEANE',
#         'CARLISLE', 'WEST DORSET', 'BASILDON', 'HARLOW', 'HERTSMERE',
#         'WELWYN HATFIELD', 'CANTERBURY', 'NORTH TYNESIDE',
#         'NEATH PORT TALBOT', 'DERBYSHIRE DALES', 'OADBY AND WIGSTON',
#         'ROCHFORD', 'RYEDALE', 'GATESHEAD', 'OGWR',
#         'PRESELI PEMBROKESHIRE', 'NORTH DORSET', 'MID SUFFOLK',
#         'STEVENAGE', 'SUTTON', 'DENBIGHSHIRE', 'WEST LANCASHIRE',
#         'HAMBLETON', 'ST EDMUNDSBURY', 'ADUR', 'CRAWLEY',
#         'BARROW-IN-FURNESS', 'MELTON', 'HYNDBURN', 'WEST DEVON', 'GOSPORT',
#         'ISLES OF SCILLY'], dtype=object), 354)

# %%
# London districts
london_districts = data.loc[data['county'] == 'GREATER LONDON', 'district'].unique().tolist()
london_districts, len(london_districts)
# Out:
# (['HARINGEY',
#   'KENSINGTON AND CHELSEA',
#   'CITY OF WESTMINSTER',
#   'WALTHAM FOREST',
#   'HACKNEY',
#   'WANDSWORTH',
#   'REDBRIDGE',
#   'ISLINGTON',
#   'EALING',
#   'HAMMERSMITH AND FULHAM',
#   'TOWER HAMLETS',
#   'MERTON',
#   'SOUTHWARK',
#   'NEWHAM',
#   'CROYDON',
#   'HILLINGDON',
#   'BEXLEY',
#   'LEWISHAM',
#   'HAVERING',
#   'RICHMOND UPON THAMES',
#   'HOUNSLOW',
#   'KINGSTON UPON THAMES',
#   'CAMDEN',
#   'LAMBETH',
#   'BARNET',
#   'BROMLEY',
#   'BRENT',
#   'HARROW',
#   'ENFIELD',
#   'GREENWICH',
#   'CITY OF LONDON',
#   'BARKING AND DAGENHAM',
#   'SUTTON'],
#  33)

# %% [markdown]
# ### Sales Volume in Latest Data

# %%
# Group by counties
yr_2018 = data[data['date_of_transfer'].dt.year == 2018]
print(f"Number of properties = {len(yr_2018.index)}")
latest_counties = yr_2018[['price']].groupby(yr_2018['county']).agg(f)
latest_counties['price','avg'] = latest_counties['price', 'sum'] / latest_counties['price','count']
latest_counties.columns = [col[1] for col in latest_counties.columns]
latest_counties.sort_values(['sum'], ascending=False, inplace=True)
latest_counties
# Out:
# Number of properties = 80329
#                                    sum  count            avg
# county
# GREATER LONDON              7593624365   8656  877267.140134
# WEST MIDLANDS               1628905627   3349  486385.675426
# KENT                         909414324   2392  380189.934783
# SURREY                       882170946   1551  568775.593810
# ESSEX                        877737510   2265  387522.079470
# GREATER MANCHESTER           816249901   3838  212675.847056
# HERTFORDSHIRE                744330257   1396  533187.863181
# WEST YORKSHIRE               687644353   3390  202844.941888
# HAMPSHIRE                    671583174   1802  372687.665927
# WORCESTERSHIRE               603531061    931  648261.075188
# WEST SUSSEX                  468026853   1225  382062.737143
# NORTHAMPTONSHIRE             404157298   1329  304106.319037
# BUCKINGHAMSHIRE              392478483    686  572126.068513
# DEVON                        378405507   1288  293793.095497
# NORFOLK                      377998121   1468  257491.908038
# OXFORDSHIRE                  357861121    842  425013.207838
# LEICESTERSHIRE               350401509   1085  322950.699539
# CAMBRIDGESHIRE               345939712    819  422392.810745
# MERSEYSIDE                   341949667   1987  172093.440866
# LANCASHIRE                   335542675   1890  177535.806878
# GLOUCESTERSHIRE              332805718   1063  313081.578551
# SOUTH YORKSHIRE              331449006   1808  183323.565265
# LINCOLNSHIRE                 300626029   1330  226034.608271
# NORTH YORKSHIRE              289062061   1025  282011.766829
# STAFFORDSHIRE                283334745   1226  231105.012235
# SUFFOLK                      281155720   1060  265241.245283
# WARWICKSHIRE                 275923505    878  314263.673121
# EAST SUSSEX                  274907698    879  312750.509670
# CORNWALL                     272710195    970  281144.530928
# NOTTINGHAMSHIRE              269725113   1172  230140.881399
# ...                                ...    ...            ...
# RHONDDA CYNON TAFF            45549024    351  129769.299145
# CARMARTHENSHIRE               43896103    268  163791.429104
# FLINTSHIRE                    41263565    236  174845.614407
# CITY OF KINGSTON UPON HULL    40546849    323  125532.040248
# NORTH LINCOLNSHIRE            39835092    251  158705.545817
# POWYS                         39797153    179  222330.463687
# MONMOUTHSHIRE                 36461030    141  258588.865248
# CAERPHILLY                    36391095    235  154855.723404
# REDCAR AND CLEVELAND          35742084    248  144121.306452
# PEMBROKESHIRE                 33984205    178  190922.500000
# BRIDGEND                      33370281    208  160434.043269
# CONWY                         32728375    187  175018.048128
# NORTH EAST LINCOLNSHIRE       31811307    237  134224.924051
# WREXHAM                       30816196    164  187903.634146
# BLACKBURN WITH DARWEN         29973697    176  170305.096591
# BLACKPOOL                     29624931    234  126602.269231
# GWYNEDD                       29494452    187  157724.342246
# MIDDLESBROUGH                 28046068    187  149978.973262
# HALTON                        27796826    175  158839.005714
# DENBIGHSHIRE                  24844601    160  155278.756250
# DARLINGTON                    23878845    146  163553.732877
# RUTLAND                       23107645     63  366788.015873
# HARTLEPOOL                    21751238    162  134266.901235
# ISLE OF ANGLESEY              21643750    117  184989.316239
# NEATH PORT TALBOT             21259540    188  113082.659574
# CEREDIGION                    19557296    104  188050.923077
# TORFAEN                       17020056    110  154727.781818
# BLAENAU GWENT                 10878333    103  105614.883495
# MERTHYR TYDFIL                 6534950     64  102108.593750
# ISLES OF SCILLY                1070000      2  535000.000000
#
# [112 rows x 3 columns]

# %%
# Counties as percentage of UK
latest_counties['norm'] = (latest_counties['sum'] / latest_counties['sum'].sum())*100
latest_counties
# Out:
#                                    sum  count            avg       norm
# county
# GREATER LONDON              7593624365   8656  877267.140134  26.542254
# WEST MIDLANDS               1628905627   3349  486385.675426   5.693569
# KENT                         909414324   2392  380189.934783   3.178707
# SURREY                       882170946   1551  568775.593810   3.083482
# ESSEX                        877737510   2265  387522.079470   3.067986
# GREATER MANCHESTER           816249901   3838  212675.847056   2.853066
# HERTFORDSHIRE                744330257   1396  533187.863181   2.601683
# WEST YORKSHIRE               687644353   3390  202844.941888   2.403547
# HAMPSHIRE                    671583174   1802  372687.665927   2.347408
# WORCESTERSHIRE               603531061    931  648261.075188   2.109543
# WEST SUSSEX                  468026853   1225  382062.737143   1.635910
# NORTHAMPTONSHIRE             404157298   1329  304106.319037   1.412665
# BUCKINGHAMSHIRE              392478483    686  572126.068513   1.371843
# DEVON                        378405507   1288  293793.095497   1.322654
# NORFOLK                      377998121   1468  257491.908038   1.321230
# OXFORDSHIRE                  357861121    842  425013.207838   1.250844
# LEICESTERSHIRE               350401509   1085  322950.699539   1.224770
# CAMBRIDGESHIRE               345939712    819  422392.810745   1.209175
# MERSEYSIDE                   341949667   1987  172093.440866   1.195228
# LANCASHIRE                   335542675   1890  177535.806878   1.172834
# GLOUCESTERSHIRE              332805718   1063  313081.578551   1.163267
# SOUTH YORKSHIRE              331449006   1808  183323.565265   1.158525
# LINCOLNSHIRE                 300626029   1330  226034.608271   1.050788
# NORTH YORKSHIRE              289062061   1025  282011.766829   1.010368
# STAFFORDSHIRE                283334745   1226  231105.012235   0.990350
# SUFFOLK                      281155720   1060  265241.245283   0.982733
# WARWICKSHIRE                 275923505    878  314263.673121   0.964445
# EAST SUSSEX                  274907698    879  312750.509670   0.960894
# CORNWALL                     272710195    970  281144.530928   0.953213
# NOTTINGHAMSHIRE              269725113   1172  230140.881399   0.942779
# ...                                ...    ...            ...        ...
# RHONDDA CYNON TAFF            45549024    351  129769.299145   0.159209
# CARMARTHENSHIRE               43896103    268  163791.429104   0.153432
# FLINTSHIRE                    41263565    236  174845.614407   0.144230
# CITY OF KINGSTON UPON HULL    40546849    323  125532.040248   0.141725
# NORTH LINCOLNSHIRE            39835092    251  158705.545817   0.139237
# POWYS                         39797153    179  222330.463687   0.139104
# MONMOUTHSHIRE                 36461030    141  258588.865248   0.127443
# CAERPHILLY                    36391095    235  154855.723404   0.127199
# REDCAR AND CLEVELAND          35742084    248  144121.306452   0.124931
# PEMBROKESHIRE                 33984205    178  190922.500000   0.118786
# BRIDGEND                      33370281    208  160434.043269   0.116640
# CONWY                         32728375    187  175018.048128   0.114397
# NORTH EAST LINCOLNSHIRE       31811307    237  134224.924051   0.111191
# WREXHAM                       30816196    164  187903.634146   0.107713
# BLACKBURN WITH DARWEN         29973697    176  170305.096591   0.104768
# BLACKPOOL                     29624931    234  126602.269231   0.103549
# GWYNEDD                       29494452    187  157724.342246   0.103093
# MIDDLESBROUGH                 28046068    187  149978.973262   0.098030
# HALTON                        27796826    175  158839.005714   0.097159
# DENBIGHSHIRE                  24844601    160  155278.756250   0.086840
# DARLINGTON                    23878845    146  163553.732877   0.083465
# RUTLAND                       23107645     63  366788.015873   0.080769
# HARTLEPOOL                    21751238    162  134266.901235   0.076028
# ISLE OF ANGLESEY              21643750    117  184989.316239   0.075652
# NEATH PORT TALBOT             21259540    188  113082.659574   0.074309
# CEREDIGION                    19557296    104  188050.923077   0.068359
# TORFAEN                       17020056    110  154727.781818   0.059491
# BLAENAU GWENT                 10878333    103  105614.883495   0.038023
# MERTHYR TYDFIL                 6534950     64  102108.593750   0.022842
# ISLES OF SCILLY                1070000      2  535000.000000   0.003740
#
# [112 rows x 4 columns]

# %% [markdown]
# ### Number of Houses sold for over £1Million

# %%
over_mill = yr_2018[yr_2018['price'] > 1000000]
over_mill_by_county = over_mill[['price']].groupby(yr_2018['county']).agg(f)
over_mill_by_county.columns = [col[1] for col in over_mill_by_county.columns]
over_mill_by_county.sort_values(['count'], ascending=False, inplace=True)
over_mill_by_county['norm'] = (over_mill_by_county['sum'] / over_mill_by_county['sum'].sum())*100
over_mill_by_county
# Out:
#                                      sum  count       norm
# county
# GREATER LONDON                4201718896   1053  49.871833
# SURREY                         271951032    137   3.227892
# HERTFORDSHIRE                  213982573     82   2.539842
# KENT                           186472951     59   2.213320
# ESSEX                          161693873     52   1.919207
# BUCKINGHAMSHIRE                137977242     51   1.637705
# GREATER MANCHESTER             127123486     44   1.508878
# HAMPSHIRE                       91581750     42   1.087019
# OXFORDSHIRE                     66988084     37   0.795108
# WEST MIDLANDS                  980242348     37  11.634877
# WEST SUSSEX                     65988912     34   0.783248
# CAMBRIDGESHIRE                  96806700     24   1.149036
# GLOUCESTERSHIRE                 47266500     23   0.561024
# CORNWALL                        39527180     21   0.469163
# CHESHIRE EAST                   26743571     18   0.317430
# WINDSOR AND MAIDENHEAD          45816000     17   0.543808
# DEVON                           33353664     17   0.395888
# BRIGHTON AND HOVE               26253639     15   0.311615
# WARWICKSHIRE                    37584972     15   0.446111
# WEST YORKSHIRE                  98671148     15   1.171166
# BATH AND NORTH EAST SOMERSET    34191094     14   0.405827
# WILTSHIRE                       19992500     14   0.237299
# MERSEYSIDE                      34781000     13   0.412829
# NORTHAMPTONSHIRE                98037382     12   1.163644
# POOLE                           19645855     12   0.233184
# WORCESTERSHIRE                 362128972     12   4.298249
# SOMERSET                        18734999     11   0.222373
# NOTTINGHAMSHIRE                 47116768     11   0.559247
# LANCASHIRE                      19860281     11   0.235729
# EAST SUSSEX                     18238948     11   0.216485
# ...                                  ...    ...        ...
# NORTHUMBERLAND                   6636775      3   0.078774
# BLACKBURN WITH DARWEN            6876887      3   0.081624
# LEICESTER                        4748989      3   0.056368
# NORTH SOMERSET                   5340000      3   0.063383
# LUTON                           15200000      3   0.180415
# NEWPORT                         15500000      3   0.183976
# MILTON KEYNES                    3680000      3   0.043679
# CENTRAL BEDFORDSHIRE             5550000      2   0.065875
# TORBAY                           5263400      2   0.062473
# THURROCK                         8688898      2   0.103132
# MEDWAY                           4030000      2   0.047834
# SOUTHEND-ON-SEA                  2695000      2   0.031988
# POWYS                            3455200      2   0.041011
# SOUTH GLOUCESTERSHIRE            5975000      2   0.070920
# HEREFORDSHIRE                   23169831      2   0.275012
# FLINTSHIRE                       1100000      1   0.013056
# WREXHAM                          2000000      1   0.023739
# MONMOUTHSHIRE                    1080000      1   0.012819
# ISLE OF WIGHT                    1375000      1   0.016320
# BLACKPOOL                        2400000      1   0.028487
# CAERPHILLY                       2340000      1   0.027774
# CITY OF PLYMOUTH                 2400000      1   0.028487
# THE VALE OF GLAMORGAN            1510000      1   0.017923
# RHONDDA CYNON TAFF               3521215      1   0.041795
# CITY OF DERBY                    3000000      1   0.035608
# CITY OF KINGSTON UPON HULL       2500000      1   0.029673
# RUTLAND                          1360000      1   0.016142
# SHROPSHIRE                      12400000      1   0.147180
# STOCKTON-ON-TEES                 4750000      1   0.056380
# MIDDLESBROUGH                    1838652      1   0.021824
#
# [91 rows x 3 columns]

# %% [markdown]
# ### Top 1% and 5% Entry point

# %%
county_2018.describe()
# Out:
#               price
# count  2.392000e+03
# mean   3.801899e+05
# std    9.750289e+05
# min    1.900000e+02
# 25%    2.180000e+05
# 50%    2.872500e+05
# 75%    3.899962e+05
# max    3.300000e+07

# %%
county = 'KENT'
top= 5
county_2018 = yr_2018[yr_2018['county'] == county ]

county_2018.sort_values('price', ascending=False, inplace=True)
county_median = county_2018['price'].median()
print(f'County median = {county_median}')
print(county_2018['price'].head(20))
county_2018 

num_props = len(county_2018.index)
print(f"Num props: {num_props}")
half_num = int(num_props/2)
print(f"Half the number of props = {half_num}")
mid_window = county_2018.iloc[half_num-2: half_num+2,0:2]
print(f'Middle Window: \n {mid_window}')
      
      
top_percentile = np.percentile(county_2018['price'], top, interpolation='higher')
print(f'Median calculated using np.percentile {top_percentile}')

plt.hist(county_2018['price'])
# Out:
# County median = 287250.0
# 8475     33000000
# 15740    26500000
# 15739    11925000
# 87566    10700000
# 13625     7172835
# 12730     6850000
# 15726     4600000
# 12731     4400489
# 15755     4300000
# 14175     3700000
# 14693     3050000
# 13645     2885071
# 50995     2635000
# 13646     2350000
# 12733     2255000
# 15741     2100000
# 15738     2029252
# 8832      2000000
# 13640     2000000
# 62170     1910000
# Name: price, dtype: int64
# Num props: 2392
# Half the number of props = 1196.0
# /Users/eric/e-prop/et/venv/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-f39e34336c0c> in <module>()
#      13 half_num = num_props/2
#      14 print(f"Half the number of props = {half_num}")
# ---> 15 mid_window = county_2018.iloc[half_num-2: half_num+2,0:2]
#      16 print(f'Middle Window: \n {mid_window}')
#      17
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2027                 continue
#    2028
# -> 2029             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    2030
#    2031             # if the dim was reduced, then pass a lower-dim the next time
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2078
#    2079         if isinstance(key, slice):
# -> 2080             return self._get_slice_axis(key, axis=axis)
#    2081
#    2082         if isinstance(key, list):
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2046             return obj.copy(deep=False)
#    2047
# -> 2048         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2049         if isinstance(slice_obj, slice):
#    2050             return self._slice(slice_obj, axis=axis, kind='iloc')
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_slice_indexer(self, key, axis)
#     264         # if we are accessing via lowered dim, use the last dim
#     265         ax = self.obj._get_axis(min(axis, self.ndim - 1))
# --> 266         return ax._convert_slice_indexer(key, kind=self.name)
#     267
#     268     def _has_valid_setitem_indexer(self, indexer):
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in _convert_slice_indexer(self, key, kind)
#    1703         # validate iloc
#    1704         if kind == 'iloc':
# -> 1705             return slice(self._validate_indexer('slice', key.start, kind),
#    1706                          self._validate_indexer('slice', key.stop, kind),
#    1707                          self._validate_indexer('slice', key.step, kind))
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in _validate_indexer(self, form, key, kind)
#    4143             pass
#    4144         elif kind in ['iloc', 'getitem']:
# -> 4145             self._invalid_indexer(form, key)
#    4146         return key
#    4147
#
# ~/e-prop/et/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    1861                         "indexers [{key}] of {kind}".format(
#    1862                             form=form, klass=type(self), key=key,
# -> 1863                             kind=type(key)))
#    1864
#    1865     def get_duplicates(self):
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.numeric.Int64Index'> with these indexers [1194.0] of <class 'float'>
